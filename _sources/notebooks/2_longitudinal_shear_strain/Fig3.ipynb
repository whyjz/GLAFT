# %%
# Developer's setting
# %load_ext autoreload
# %autoreload 2

# %%
import glaft
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df = pd.read_csv('../manifest.csv', dtype=str)
in_shp = '/home/jovyan/Projects/PX_comparison/Bedrock_shp/glacier_V1_Kaskawulsh_s_inwardBuffer600m.shp'
selected_cases = df.loc[[64, 63, 99]]
selected_cases
# Out:
#                      Date Duration (days) Template size (px)  \
# 64  LS8-20180802-20180818              16                 64
# 63  LS8-20180802-20180818              16                 64
# 99  LS8-20180802-20180818              16                 65
#
#    Template size (m) Pixel spacing (px) Pixel spacing (m) Prefilter  \
# 64               960                  1                15      NAOF
# 63               960                  1                15       Gau
# 99               975                  1                15       Gau
#
#                 Subpixel Software  \
# 64  16-node oversampling    CARST
# 63  16-node oversampling    CARST
# 99             parabolic     Vmap
#
#                                                    Vx  \
# 64  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 63  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 99  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...
#
#                                                    Vy
# 64  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 63  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 99  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...

# %%
exps = {}

for idx, row in selected_cases.iterrows():
    exp = glaft.Velocity(vxfile=row.Vx, vyfile=row.Vy, on_ice_area=in_shp, kde_gridsize=60, thres_sigma=2.0)
    exp.longitudinal_shear_analysis()
    exps[idx] = exp
# Out:
# Running clip_on_ice_area
# Running get_grid_spacing
# Running calculate_flow_theta
# Running calculate_strain_rate
# Running prep_strain_rate_kde
# Running calculate_xystd
# Running calculate_bandwidth
# Running calculate_kde
# Running construct_crude_mesh
# Running eval_crude_mesh
# Running construct_fine_mesh
# Running eval_fine_mesh
# Running thresholding_fine_mesh
# Running thresholding_metric
# Running clip_on_ice_area
# Running get_grid_spacing
# Running calculate_flow_theta
# Running calculate_strain_rate
# Running prep_strain_rate_kde
# Running calculate_xystd
# Running calculate_bandwidth
# Running calculate_kde
# Running construct_crude_mesh
# Running eval_crude_mesh
# Running construct_fine_mesh
# Running eval_fine_mesh
# Running thresholding_fine_mesh
# Running thresholding_metric
# Running clip_on_ice_area
# Running get_grid_spacing
# Running calculate_flow_theta
# Running calculate_strain_rate
# Running prep_strain_rate_kde
# Running calculate_xystd
# Running calculate_bandwidth
# Running calculate_kde
# Running construct_crude_mesh
# Running eval_crude_mesh
# Running construct_fine_mesh
# Running eval_fine_mesh
# Running thresholding_fine_mesh
# Running thresholding_metric

# %%
font = {'size'   : 14}
mpl.rc('font', **font)
axes_settings = {'linewidth'   : 2}
# axes_settings = {'linewidth'   : 2, 'labelsize': 14}
mpl.rc('axes', **axes_settings)

fig, axs = plt.subplots(2, 3, figsize=(13, 6.7), constrained_layout=True)

for idx, n, label, label2 in zip([64, 63, 99], 
                                 [0, 1, 2], 
                                 ['$\\bf{(A)}$ No pre-filter', '$\\bf{(B)}$ Gaussian HPF', '$\\bf{(C)}$ NAOF'], 
                                 ['$\\bf{(D)}$ ', '$\\bf{(E)}$ ', '$\\bf{(F)}$ ']):
    exp = exps[idx]
    ax_sel = axs[0, n]
    cm_settings = glaft.show_velocomp(exp.vxfile, ax=ax_sel)
    ax_sel.set_title(label)
    ax_sel = axs[1, n]
    exp.plot_zoomed_extent(metric=2, ax=ax_sel)
    ax_sel.axis('equal')
    ax_sel.set_xlim(-0.1, 0.1)
    ax_sel.set_ylim(-0.1, 0.1)
    ax_sel.set_xlabel('$V_x$ ({})'.format(exp.velocity_unit))
    metric_text = ax_sel.get_title()
    ax_sel.set_title(label2 + metric_text[:-8])

    
mappable = glaft.prep_colorbar_mappable(**cm_settings)
fig.colorbar(mappable, ax=[axs[0, 2]], location='right', shrink=0.75, aspect=10, label='$V_x$ ({})'.format(exp.velocity_unit))
axs[1, 0].set_ylabel('$V_y$ ({})'.format(exp.velocity_unit))

fig.patch.set_facecolor('xkcd:white')
# fig.savefig('Fig3.png', dpi=300)
# fig.savefig('Fig3.pdf')

# %%
exps[64].metric_alongflow_shear
# Out:
# 0.002068524030083018

# %%
demo
# Out:
# Date                                              LS8-20180802-20180818
# Duration (days)                                                      16
# Template size (px)                                                   64
# Template size (m)                                                   960
# Pixel spacing (px)                                                    1
# Pixel spacing (m)                                                    15
# Prefilter                                                          NAOF
# Subpixel                                           16-node oversampling
# Software                                                          CARST
# Vx                    /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# Vy                    /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# Name: 64, dtype: object

# %%
demo = df.loc[64]

tmpexp = glaft.Velocity(vxfile=demo.Vx, vyfile=demo.Vy, on_ice_area=in_shp, kde_gridsize=60, thres_sigma=2.0)
tmpexp.longitudinal_shear_analysis()
tmpexp.metric_alongflow_shear
# Out:
# Running clip_on_ice_area
# Running get_grid_spacing
# Running calculate_flow_theta
# Running calculate_strain_rate
# Running prep_strain_rate_kde
# Running calculate_xystd
# Running calculate_bandwidth
# Running calculate_kde
# Running construct_crude_mesh
# Running eval_crude_mesh
# Running construct_fine_mesh
# Running eval_fine_mesh
# Running thresholding_fine_mesh
# Running thresholding_metric
# 0.0499868735364598

# %%
tmpexp.metric_alongflow_shear
# Out:
# 0.002068524030083018

# %%
in_shp = '/home/jovyan/Projects/PX_comparison/Bedrock_shp/glacier_V1_Kaskawulsh_s_inwardBuffer600m.shp'

# %%
tmpexp.metric_alongflow_shear
# Out:
# 0.0499868735364598

# %%
tmpexp.plot_zoomed_extent(metric=2)
plt.xlim(-0.1, 0.1)
plt.ylim(-0.1, 0.1)
# Out:
# (-0.1, 0.1)

# %%
selected_cases
# Out:
#                      Date Duration (days) Template size (px)  \
# 64  LS8-20180802-20180818              16                 64
# 63  LS8-20180802-20180818              16                 64
# 99  LS8-20180802-20180818              16                 65
#
#    Template size (m) Pixel spacing (px) Pixel spacing (m) Prefilter  \
# 64               960                  1                15      NAOF
# 63               960                  1                15       Gau
# 99               975                  1                15       Gau
#
#                 Subpixel Software  \
# 64  16-node oversampling    CARST
# 63  16-node oversampling    CARST
# 99             parabolic     Vmap
#
#                                                    Vx  \
# 64  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 63  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 99  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...
#
#                                                    Vy
# 64  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 63  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 99  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...

# %%
exps2 = {}

for idx, row in selected_cases.iterrows():
    exp2 = glaft.Velocity(vxfile=row.Vx, vyfile=row.Vy, on_ice_area=in_shp, kde_gridsize=60, thres_sigma=2.0)
    exp2.longitudinal_shear_analysis()
    exps2[idx] = exp2
# Out:
# Running clip_on_ice_area
# Running get_grid_spacing
# Running calculate_flow_theta
# Running calculate_strain_rate
# Running prep_strain_rate_kde
# Running calculate_xystd
# Running calculate_bandwidth
# Running calculate_kde
# Running construct_crude_mesh
# Running eval_crude_mesh
# Running construct_fine_mesh
# Running eval_fine_mesh
# Running thresholding_fine_mesh
# Running thresholding_metric
# Running clip_on_ice_area
# Running get_grid_spacing
# Running calculate_flow_theta
# Running calculate_strain_rate
# Running prep_strain_rate_kde
# Running calculate_xystd
# Running calculate_bandwidth
# Running calculate_kde
# Running construct_crude_mesh
# Running eval_crude_mesh
# Running construct_fine_mesh
# Running eval_fine_mesh
# Running thresholding_fine_mesh
# Running thresholding_metric
# Running clip_on_ice_area
# Running get_grid_spacing
# Running calculate_flow_theta
# Running calculate_strain_rate
# Running prep_strain_rate_kde
# Running calculate_xystd
# Running calculate_bandwidth
# Running calculate_kde
# Running construct_crude_mesh
# Running eval_crude_mesh
# Running construct_fine_mesh
# Running eval_fine_mesh
# Running thresholding_fine_mesh
# Running thresholding_metric

# %%
font = {'size'   : 14}
mpl.rc('font', **font)
axes_settings = {'linewidth'   : 2}
# axes_settings = {'linewidth'   : 2, 'labelsize': 14}
mpl.rc('axes', **axes_settings)

fig, axs = plt.subplots(2, 3, figsize=(13, 6.7), constrained_layout=True)

for idx, n, label, label2 in zip([64, 63, 99], 
                                 [0, 1, 2], 
                                 ['$\\bf{(A)}$ CARST (NAOF)', '$\\bf{(B)}$ CAUST (Gaussian)', '$\\bf{(C)}$ Vmap (Gaussian)'], 
                                 ['$\\bf{(D)}$ \n ', '$\\bf{(E)}$ \n ', '$\\bf{(F)}$ \n ']):
    exp = exps2[idx]
    ax_sel = axs[0, n]
    cm_settings = glaft.show_velocomp(exp.vxfile, ax=ax_sel)
    ax_sel.set_title(label)
    ax_sel = axs[1, n]
    exp.plot_zoomed_extent(metric=2, ax=ax_sel)
    ax_sel.axis('equal')
    ax_sel.set_xlim(-0.1, 0.1)
    ax_sel.set_ylim(-0.1, 0.1)
    ax_sel.set_xlabel("$\dot{\epsilon}_{x'x'}$ (1/day)")
    metric_text = ax_sel.get_title()
    ax_sel.set_title(label2 + metric_text[:-5])

    
mappable = glaft.prep_colorbar_mappable(**cm_settings)
fig.colorbar(mappable, ax=[axs[0, 2]], location='right', shrink=0.75, aspect=10, label='$V_x$ ({})'.format(exp.velocity_unit))
axs[1, 0].set_ylabel("$\dot{\epsilon}_{x'y'}$ (1/day)")

fig.patch.set_facecolor('xkcd:white')
# fig.savefig('Fig3.png', dpi=300)
# fig.savefig('Fig3.pdf')

# %%
font = {'size'   : 14}
mpl.rc('font', **font)
axes_settings = {'linewidth'   : 2}
# axes_settings = {'linewidth'   : 2, 'labelsize': 14}
mpl.rc('axes', **axes_settings)

vmax = exps2[64].metric_alongflow_normal

fig, axs = plt.subplots(3, 3, figsize=(13, 10), constrained_layout=True)

for idx, n, label, label2, label3 in zip([64, 63, 99], 
                                         [0, 1, 2], 
                                         ['$\\bf{(A)}$ CARST (NAOF)', '$\\bf{(B)}$ CAUST (Gaussian)', '$\\bf{(C)}$ Vmap (Gaussian)'], 
                                         ['$\\bf{(D)}$ \n ', '$\\bf{(E)}$ \n ', '$\\bf{(F)}$ \n '],
                                         ['$\\bf{(G)}$', '$\\bf{(H)}$', '$\\bf{(I)}$']):
    exp = exps2[idx]
    ax_sel = axs[0, n]
    cm_settings = glaft.show_velocomp(exp.vxfile, ax=ax_sel)
    ax_sel.set_title(label)
    ax_sel = axs[1, n]
    exp.plot_zoomed_extent(metric=2, ax=ax_sel)
    ax_sel.axis('equal')
    ax_sel.set_xlim(-0.1, 0.1)
    ax_sel.set_ylim(-0.1, 0.1)
    ax_sel.set_xlabel("$\dot{\epsilon}_{x'x'}$ (1/day)")
    metric_text = ax_sel.get_title()
    ax_sel.set_title(label2 + metric_text[:-5])
    ax_sel = axs[2, n]
    mappable2 = exp.plot_strain_map(ax=ax_sel, vmax=vmax)
    ax_sel.set_title(label3)

    
mappable = glaft.prep_colorbar_mappable(**cm_settings)
fig.colorbar(mappable, ax=[axs[0, 2]], location='right', shrink=0.75, aspect=10, label='$V_x$ ({})'.format(exp.velocity_unit))
axs[1, 0].set_ylabel("$\dot{\epsilon}_{x'y'}$ (1/day)")
fig.colorbar(mappable2, ax=[axs[2, 2]], location='right', shrink=0.75, aspect=10, label="$\sqrt{\dot{\epsilon}_{x'x'}^2 + \dot{\epsilon}_{x'y'}^2}$")

fig.patch.set_facecolor('xkcd:white')
fig.savefig('Fig3.png', dpi=300)
# fig.savefig('Fig3.pdf')

# %%
font = {'size'   : 14}
mpl.rc('font', **font)
axes_settings = {'linewidth'   : 2}
# axes_settings = {'linewidth'   : 2, 'labelsize': 14}
mpl.rc('axes', **axes_settings)

vmax = exps2[64].metric_alongflow_normal

fig, axs = plt.subplots(3, 3, figsize=(13, 10), constrained_layout=True)

for idx, n, label, label2, label3 in zip([64, 63, 99], 
                                         [0, 1, 2], 
                                         ['$\\bf{(A)}$ CARST (NAOF)', '$\\bf{(B)}$ CARST (Gaussian)', '$\\bf{(C)}$ Vmap (Gaussian)'], 
                                         ['$\\bf{(D)}$ \n ', '$\\bf{(E)}$ \n ', '$\\bf{(F)}$ \n '],
                                         ['$\\bf{(G)}$', '$\\bf{(H)}$', '$\\bf{(I)}$']):
    exp = exps2[idx]
    ax_sel = axs[0, n]
    cm_settings = glaft.show_velocomp(exp.vxfile, ax=ax_sel)
    ax_sel.set_title(label)
    ax_sel = axs[1, n]
    exp.plot_zoomed_extent(metric=2, ax=ax_sel)
    ax_sel.axis('equal')
    ax_sel.set_xlim(-0.3, 0.3)
    ax_sel.set_ylim(-0.3, 0.3)
    ax_sel.set_xlabel("$\dot{\epsilon}_{x'x'}$ (1/day)")
    metric_text = ax_sel.get_title()
    ax_sel.set_title(label2 + metric_text[:-5])
    ax_sel = axs[2, n]
    mappable2 = exp.plot_strain_map(ax=ax_sel, vmax=vmax)
    ax_sel.set_title(label3)

    
mappable = glaft.prep_colorbar_mappable(**cm_settings)
fig.colorbar(mappable, ax=[axs[0, 2]], location='right', shrink=0.75, aspect=10, label='$V_x$ ({})'.format(exp.velocity_unit))
axs[1, 0].set_ylabel("$\dot{\epsilon}_{x'y'}$ (1/day)")
fig.colorbar(mappable2, ax=[axs[2, 2]], location='right', shrink=0.75, aspect=10, label="$\sqrt{\dot{\epsilon}_{x'x'}^2 + \dot{\epsilon}_{x'y'}^2}$ (1/day)")

fig.patch.set_facecolor('xkcd:white')
fig.savefig('Fig3.png', dpi=300)
# fig.savefig('Fig3.pdf')
