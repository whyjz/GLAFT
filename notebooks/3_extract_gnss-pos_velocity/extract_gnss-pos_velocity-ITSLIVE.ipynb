# %% [markdown]
# # ITS_LIVE: Extract velocity map data at GNSS locations

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from glaft.georaster import Raster

# %%
import rasterio
# import matplotlib.pyplot as plt
# from rasterio.plot import show as rio_show
# import matplotlib as mpl
import pandas as pd
import geopandas as gpd
import numpy as np
# import glob
from datetime import datetime
from pyproj import Transformer

# %%
df = pd.read_csv('../results_ITSLIVE.csv', dtype=str)
df
# Out:
#                      Label Start date  End date Duration (days)  \
# 0    LS8-20180304-20180405   20180304  20180405              32
# 1    LS8-20180405-20180421   20180405  20180421              16
# 2    LS8-20180421-20180523   20180421  20180523              32
# 3    LS8-20180523-20180608   20180523  20180608              16
# 4    LS8-20180412-20180428   20180412  20180428              16
# 5    LS8-20180428-20180802   20180428  20180802              96
# 6    LS8-20180802-20180818   20180802  20180818              16
# 7    LS8-20180818-20180903   20180818  20180903              16
# 8    LS8-20180903-20181005   20180903  20181005              32
# 9   Sen2-20180306-20180316   20180306  20180316              10
# 10  Sen2-20180316-20180515   20180316  20180515              60
# 11  Sen2-20180329-20180508   20180329  20180508              40
# 12  Sen2-20180508-20180518   20180508  20180518              10
# 13  Sen2-20180508-20180627   20180508  20180627              50
# 14  Sen2-20180515-20180619   20180515  20180619              35
# 15  Sen2-20180518-20180523   20180518  20180523               5
# 16  Sen2-20180627-20180722   20180627  20180722              25
# 17  Sen2-20180704-20180724   20180704  20180724              20
# 18  Sen2-20180724-20180729   20180724  20180729               5
# 19  Sen2-20180727-20180801   20180727  20180801               5
# 20  Sen2-20180304-20180314   20180304  20180314              10
# 21  Sen2-20180314-20180329   20180314  20180329              15
# 22  Sen2-20180523-20180612   20180523  20180612              20
# 23  Sen2-20180612-20180627   20180612  20180627              15
# 24  Sen2-20180619-20180704   20180619  20180704              15
# 25  Sen2-20180722-20180727   20180722  20180727               5
# 26  Sen2-20180729-20180818   20180729  20180818              20
# 27  Sen2-20180801-20180811   20180801  20180811              10
# 28  Sen2-20180811-20180831   20180811  20180831              20
# 29  Sen2-20180818-20180917   20180818  20180917              30
# 30  Sen2-20180831-20180910   20180831  20180910              10
# 31  Sen2-20180910-20180920   20180910  20180920              10
# 32  Sen2-20180917-20181002   20180917  20181002              15
# 33  Sen2-20180920-20180930   20180920  20180930              10
# 34  Sen2-20180930-20181005   20180930  20181005               5
#
#    Template size (px)  Template size (m) Pixel spacing (px) Pixel spacing (m)  \
# 0                 NaN  varying (240-480)                NaN               120
# 1                 NaN  varying (240-480)                NaN               120
# 2                 NaN  varying (240-480)                NaN               120
# 3                 NaN  varying (240-480)                NaN               120
# 4                 NaN  varying (240-480)                NaN               120
# 5                 NaN  varying (240-480)                NaN               120
# 6                 NaN  varying (240-480)                NaN               120
# 7                 NaN  varying (240-480)                NaN               120
# 8                 NaN  varying (240-480)                NaN               120
# 9                 NaN  varying (240-480)                NaN               120
# 10                NaN  varying (240-480)                NaN               120
# 11                NaN  varying (240-480)                NaN               120
# 12                NaN  varying (240-480)                NaN               120
# 13                NaN  varying (240-480)                NaN               120
# 14                NaN  varying (240-480)                NaN               120
# 15                NaN  varying (240-480)                NaN               120
# 16                NaN  varying (240-480)                NaN               120
# 17                NaN  varying (240-480)                NaN               120
# 18                NaN  varying (240-480)                NaN               120
# 19                NaN  varying (240-480)                NaN               120
# 20                NaN  varying (240-480)                NaN               120
# 21                NaN  varying (240-480)                NaN               120
# 22                NaN  varying (240-480)                NaN               120
# 23                NaN  varying (240-480)                NaN               120
# 24                NaN  varying (240-480)                NaN               120
# 25                NaN  varying (240-480)                NaN               120
# 26                NaN  varying (240-480)                NaN               120
# 27                NaN  varying (240-480)                NaN               120
# 28                NaN  varying (240-480)                NaN               120
# 29                NaN  varying (240-480)                NaN               120
# 30                NaN  varying (240-480)                NaN               120
# 31                NaN  varying (240-480)                NaN               120
# 32                NaN  varying (240-480)                NaN               120
# 33                NaN  varying (240-480)                NaN               120
# 34                NaN  varying (240-480)                NaN               120
#
#                          Prefilter                         Subpixel  \
# 0   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 1   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 2   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 3   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 4   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 5   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 6   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 7   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 8   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 9   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 10  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 11  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 12  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 13  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 14  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 15  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 16  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 17  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 18  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 19  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 20  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 21  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 22  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 23  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 24  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 25  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 26  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 27  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 28  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 29  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 30  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 31  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 32  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 33  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
# 34  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)
#
#                Software                                                 Vx  \
# 0   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 1   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 2   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 3   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 4   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 5   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 6   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 7   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 8   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 9   ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 10  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 11  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 12  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 13  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 14  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 15  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 16  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 17  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 18  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 19  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 20  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 21  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 22  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 23  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 24  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 25  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 26  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 27  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 28  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 29  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 30  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 31  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 32  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 33  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
# 34  ITS_LIVE (autoRIFT)  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...
#
#                                                    Vy Assigned-x-error  \
# 0   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             47.7
# 1   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...            119.6
# 2   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             92.5
# 3   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             75.5
# 4   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...            132.2
# 5   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             32.0
# 6   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             48.3
# 7   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             49.9
# 8   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             38.7
# 9   /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...            102.3
# 10  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             43.0
# 11  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             52.1
# 12  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...            175.7
# 13  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             37.1
# 14  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             45.3
# 15  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...            133.3
# 16  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             39.0
# 17  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             36.7
# 18  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             70.3
# 19  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             67.1
# 20  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...            121.4
# 21  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             72.3
# 22  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             50.4
# 23  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             80.5
# 24  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             61.6
# 25  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             76.0
# 26  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             24.8
# 27  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             39.1
# 28  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             33.4
# 29  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             32.9
# 30  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             65.7
# 31  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             73.9
# 32  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             54.4
# 33  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...             78.2
# 34  /home/jovyan/Projects/PX_comparison/PX/ITS_LIV...            103.5
#
#    Assigned-y-error   SAV-uncertainty-x   SAV-uncertainty-y  \
# 0              32.6    54.6898472387492   44.43550088148372
# 1              71.7  139.11564778386023  121.72619181087768
# 2              48.2  136.50749745725778   81.16662010972085
# 3              64.0    84.6755005418857   71.44495358221604
# 4              68.8  103.47791768487576   96.80192299552894
# 5              18.5   32.36846681024471   34.60077486612366
# 6              44.9   40.35395714351298   35.30971250057386
# 7              47.6   43.38566683970623  43.385666839706225
# 27   0.7354228868979078   -1.5784742956326312   23.04281222284931
# 28   -11.25416432539825    -2.322023475056895   33.15908694894581
# 29  -13.345803932358123     9.576773113867759   26.38014745549362
# 30  -13.442559247898402     6.688511849579669  29.927884615384613
# 31  -24.223335845762705    -5.223335845762705   29.58214624881291
# 32   -35.97636304405481   -19.996623292007826  20.870015535991715
# 33   -6.051555911440147    3.0171853038133634    30.6369785794814
# 34    2.686647930133063    1.3133520698669372  29.920109956189332

# %%
# All GNSS coordinates are in EPSG 32607 and have to be reprojected to EPSG3413 before sampling the geotiffs.
transformer = Transformer.from_crs("epsg:32607", "epsg:3413")

# %%
GPS_root = '/home/jovyan/Projects/PX_comparison/GPS/'

for idx, row in df.iterrows():
    startdate = datetime.strptime(row['Start date'], '%Y%m%d')
    enddate = datetime.strptime(row['End date'], '%Y%m%d')
    timedel = enddate - startdate
    duration = timedel.days / 365     # in yrs
    startdate_gpsstr = startdate.strftime('%Y-%m-%d')
    enddate_gpsstr = enddate.strftime('%Y-%m-%d')
    gps_file = GPS_root + 'Kaskawulsh_{}_to_{}_GPS'.format(enddate_gpsstr, startdate_gpsstr)
    
    gps = pd.read_csv(gps_file)
    ######## Prep corrdinates in EPSG3413 
    for idx2, row2 in gps.iterrows():
        x32607 = row2.start_easting
        y32607 = row2.start_northing
        x3413, y3413 = transformer.transform(x32607, y32607)
        gps.loc[idx2, 'start_easting_3413'] = x3413
        gps.loc[idx2, 'start_northing_3413'] = y3413
        x32607 = row2.end_easting
        y32607 = row2.end_northing
        x3413, y3413 = transformer.transform(x32607, y32607)
        gps.loc[idx2, 'end_easting_3413'] = x3413
        gps.loc[idx2, 'end_northing_3413'] = y3413
    #########
    # This is beginning coordinates
    gps = gpd.GeoDataFrame(gps, geometry=gpd.points_from_xy(gps['end_easting_3413'], gps['end_northing_3413']), crs='EPSG:3413')
    gps_xy = list(gps[['end_easting_3413', 'end_northing_3413']].to_records(index=False))
    
    gps['vx (m/yr)']  = (gps['start_easting_3413'] - gps['end_easting_3413']) / duration
    gps['vy (m/yr)']  = (gps['start_northing_3413'] - gps['end_northing_3413']) / duration
    gps['v (m/yr)']  = np.abs(gps['velocity (m/d)'] * 365)
    
    vx_grid = Raster(row.Vx)
    vy_grid = Raster(row.Vy)
    v_grid = Raster(row.Vx.replace('vx', 'v'))
    verr_grid = Raster(row.Vx.replace('vx', 'v_error'))
    sampled = []
    sampled2 = []
    for x, y in gps_xy:
        # print(gps_file, x, y)
        if np.isnan(x) or np.isnan(y) or np.isinf(x) or np.isinf(y):
            sampled.append([np.nan, np.nan, np.nan, np.nan])
            sampled2.append([np.nan, np.nan])
        else:
            vx_avg, vx_3by3 = vx_grid.value_at_coords(x, y, window=3, return_window=True)
            vy_avg, vy_3by3 = vy_grid.value_at_coords(x, y, window=3, return_window=True)
            vx_3by3[vx_3by3 < -9998] = np.nan   # ITSLIVE nodata = -32767
            vy_3by3[vy_3by3 < -9998] = np.nan   # ITSLIVE nodata = -32767
            vx_nn = vx_3by3[0, 1, 1]     # nearest neighbor value
            vy_nn = vy_3by3[0, 1, 1]
            if np.any(~np.isnan(vx_3by3)):
                vx_avg = np.nanmean(vx_3by3)
            else:
                vx_avg = np.nan
            if np.any(~np.isnan(vy_3by3)):
                vy_avg = np.nanmean(vy_3by3)
            else:
                vy_avg = np.nan

            # vx_nn -= float(df.loc[idx, 'SAV-peak-x'])
            # vx_avg -= float(df.loc[idx, 'SAV-peak-x'])
            # vy_nn -= float(df.loc[idx, 'SAV-peak-y'])
            # vy_avg -= float(df.loc[idx, 'SAV-peak-y'])

            sampled.append([vx_nn, vx_avg, vy_nn, vy_avg])
            
            v_avg, v_3by3 = v_grid.value_at_coords(x, y, window=3, return_window=True)
            v_3by3[v_3by3 < -9998] = np.nan   # ITSLIVE nodata = -32767
            if np.any(~np.isnan(v_3by3)):
                v_avg = np.nanmean(v_3by3)
            else:
                v_avg = np.nan
                
            verr_avg, verr_3by3 = verr_grid.value_at_coords(x, y, window=3, return_window=True)
            verr_3by3[verr_3by3 < -9998] = np.nan   # ITSLIVE nodata = -32767
            if np.any(~np.isnan(verr_3by3)):
                verr_avg = np.nanmean(verr_3by3)
            else:
                verr_avg = np.nan
            
            sampled2.append([v_avg, verr_avg])
            

    sampled = np.array(sampled)
    sampled2 = np.array(sampled2)
    # print(sampled)
    # print(row.Vx, float(df.loc[idx, 'SAV-peak-x']), float(df.loc[idx, 'SAV-peak-y']), sampled)
    
    df.loc[idx, 'pt0_vxavg'] = sampled[0, 1]
    df.loc[idx, 'pt0_vxgps'] = np.abs(gps.loc[0, 'vx (m/yr)'])
    df.loc[idx, 'pt0_vyavg'] = sampled[0, 3]
    df.loc[idx, 'pt0_vygps'] = np.abs(gps.loc[0, 'vy (m/yr)'])
    df.loc[idx, 'pt1_vxavg'] = sampled[1, 1]
    df.loc[idx, 'pt1_vxgps'] = np.abs(gps.loc[1, 'vx (m/yr)'])
    df.loc[idx, 'pt1_vyavg'] = sampled[1, 3]
    df.loc[idx, 'pt1_vygps'] = np.abs(gps.loc[1, 'vy (m/yr)'])
    df.loc[idx, 'pt2_vxavg'] = sampled[2, 1]
    df.loc[idx, 'pt2_vxgps'] = np.abs(gps.loc[2, 'vx (m/yr)'])
    df.loc[idx, 'pt2_vyavg'] = sampled[2, 3]
    df.loc[idx, 'pt2_vygps'] = np.abs(gps.loc[2, 'vy (m/yr)'])
    
    df.loc[idx, 'pt0_vxdiff'] = sampled[0, 0] - gps.loc[0, 'vx (m/yr)']
    df.loc[idx, 'pt0_vxavgdiff'] = sampled[0, 1] - gps.loc[0, 'vx (m/yr)']
    df.loc[idx, 'pt0_vydiff'] = sampled[0, 2] - gps.loc[0, 'vy (m/yr)']
    df.loc[idx, 'pt0_vyavgdiff'] = sampled[0, 3] - gps.loc[0, 'vy (m/yr)']
    df.loc[idx, 'pt1_vxdiff'] = sampled[1, 0] - gps.loc[1, 'vx (m/yr)']
    df.loc[idx, 'pt1_vxavgdiff'] = sampled[1, 1] - gps.loc[1, 'vx (m/yr)']
    df.loc[idx, 'pt1_vydiff'] = sampled[1, 2] - gps.loc[1, 'vy (m/yr)']
    df.loc[idx, 'pt1_vyavgdiff'] = sampled[1, 3] - gps.loc[1, 'vy (m/yr)']
    df.loc[idx, 'pt2_vxdiff'] = sampled[2, 0] - gps.loc[2, 'vx (m/yr)']
    df.loc[idx, 'pt2_vxavgdiff'] = sampled[2, 1] - gps.loc[2, 'vx (m/yr)']
    df.loc[idx, 'pt2_vydiff'] = sampled[2, 2] - gps.loc[2, 'vy (m/yr)']
    df.loc[idx, 'pt2_vyavgdiff'] = sampled[2, 3] - gps.loc[2, 'vy (m/yr)']
    
    df.loc[idx, 'pt0_vavg'] = sampled2[0, 0]
    df.loc[idx, 'pt0_vgps'] = gps.loc[0, 'v (m/yr)']
    df.loc[idx, 'pt0_vdiff'] = sampled2[0, 0] - gps.loc[0, 'v (m/yr)']
    df.loc[idx, 'pt0_verr'] = sampled2[0, 1]
    df.loc[idx, 'pt1_vavg'] = sampled2[1, 0]
    df.loc[idx, 'pt1_vgps'] = gps.loc[1, 'v (m/yr)']
    df.loc[idx, 'pt1_vdiff'] = sampled2[1, 0] - gps.loc[1, 'v (m/yr)']
    df.loc[idx, 'pt1_verr'] = sampled2[1, 1]  
    df.loc[idx, 'pt2_vavg'] = sampled2[2, 0]
    df.loc[idx, 'pt2_vgps'] = gps.loc[2, 'v (m/yr)']
    df.loc[idx, 'pt2_vdiff'] = sampled2[2, 0] - gps.loc[2, 'v (m/yr)']
    df.loc[idx, 'pt2_verr'] = sampled2[2, 1]

# %%
gps
# Out:
#    Unnamed: 0       date1       date2  start_easting  start_northing  \
# 0           0  2018-10-05  2018-09-30  621383.084841    6.738920e+06
# 1           1  2018-10-05  2018-09-30  610531.630118    6.737073e+06
# 2           2  2018-10-05  2018-09-30  601810.429736    6.733774e+06
#
#      end_easting  end_northing  distance_traveled (m)  velocity (m/d)  \
# 0  621381.738315  6.738918e+06               2.015470       -0.403094
# 1  610530.195434  6.737074e+06               1.703303       -0.340661
# 2  601809.124834  6.733773e+06               1.881326       -0.376265
#
#    start_easting_3413  start_northing_3413  end_easting_3413  \
# 0       -3.227459e+06        212767.842312     -3.227460e+06
# 1       -3.228240e+06        224145.144740     -3.228239e+06
# 2       -3.230736e+06        233478.821992     -3.230737e+06
#
#    end_northing_3413                         geometry   vx (m/yr)   vy (m/yr)  \
# 0      212769.385111  POINT (-3227460.401 212769.385)  102.707969 -112.624285
# 1      224146.528571  POINT (-3228239.026 224146.529)  -79.947760 -101.019600
# 2      233480.308331  POINT (-3230737.265 233480.308)   92.088135 -108.502758
#
#      v (m/yr)
# 0  147.129311
# 1  124.341145
# 2  137.336804

# %%
df
# gps
# Out:
# 22                NaN  varying (240-480)                NaN               120
# 23                NaN  varying (240-480)                NaN               120
# 24                NaN  varying (240-480)                NaN               120
# 25                NaN  varying (240-480)                NaN               120
# 26                NaN  varying (240-480)                NaN               120
# 27                NaN  varying (240-480)                NaN               120
# 28                NaN  varying (240-480)                NaN               120
# 29                NaN  varying (240-480)                NaN               120
# 30                NaN  varying (240-480)                NaN               120
# 31                NaN  varying (240-480)                NaN               120
# 32                NaN  varying (240-480)                NaN               120
# 33                NaN  varying (240-480)                NaN               120
# 34                NaN  varying (240-480)                NaN               120
#
#                          Prefilter                         Subpixel  ...  \
# 0   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 1   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 2   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 3   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 4   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 5   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 6   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 7   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 8   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 9   ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 10  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 11  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 12  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 13  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 14  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 15  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 16  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 17  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 18  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 19  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 20  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 21  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 22  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 23  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 24  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 25  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 26  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 27  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 28  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 29  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 30  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 31  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 32  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 33  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
# 34  ITS_LIVE (5x5 Wallis operator)  ITS_LIVE (16-node oversampling)  ...
#
#      pt0_vdiff    pt0_verr    pt1_vavg    pt1_vgps  pt1_vdiff    pt1_verr  \
# 0    34.784609   40.000000  126.000000  135.694853  -9.694853   37.555557
# 1  -126.097831  118.222221  143.777771         NaN        NaN   75.333336
# 2          NaN         NaN         NaN         NaN        NaN         NaN
# 3          NaN   70.875000         NaN         NaN        NaN         NaN
# 4   -60.811069  120.444443         NaN         NaN        NaN         NaN
# 5          NaN         NaN         NaN         NaN        NaN         NaN
# 6  -150.839183   46.444443  165.666672  198.998533 -33.331862   45.888889
# 7   -79.030334   48.444443  213.000000  203.338758   9.661242   48.333332
# 8   -27.823042   32.000000  197.555557  139.352737  58.202820   36.111111
# 9          NaN   95.000000  111.444443  121.110993  -9.666550   64.444443
# 10         NaN         NaN  133.444443  138.887806  -5.443363   32.111111
# 11   43.722901   46.777779  185.888885         NaN        NaN   27.000000
# 12  319.173436  152.555557         NaN         NaN        NaN         NaN
# 13   16.227695   30.555555         NaN         NaN        NaN         NaN
# 14         NaN         NaN         NaN  217.452058        NaN         NaN
# 15  124.232735  119.888885  306.000000         NaN        NaN  111.555557
# 16   40.473444   33.555557  225.000000         NaN        NaN   34.111111
# 17   40.998102   31.571428         NaN         NaN        NaN         NaN
# 18   18.784166   68.222221  164.777771  233.961658 -69.183887   67.555557
# 19   91.070190   63.222221  255.777771  221.045112  34.732659   62.333332
# 20   -3.277798  111.666664  104.222221  120.608472 -16.386251   75.333336
# 21  -25.297494   61.222221  122.555557  134.890578 -12.335021   54.555557
# 22         NaN   45.333332         NaN         NaN        NaN         NaN
# 23         NaN         NaN         NaN  252.500424        NaN         NaN
# 24    4.834796   57.000000         NaN         NaN        NaN         NaN
# 25   83.783677   73.333336         NaN         NaN        NaN         NaN
# 26   -6.945328   22.666666  191.777771  204.018336 -12.240565   22.222221
# 27 -102.352901   36.777779  228.888885  203.754900  25.133986   35.333332
# 28         NaN         NaN  232.555557  210.406048  22.149510   31.000000
# 29  -11.521102   26.888889  201.555557  177.982396  23.573161   28.111111
# 30         NaN         NaN  132.444443  151.044362 -18.599919   63.333332
# 31  -45.710553   71.222221  166.000000  141.091697  24.908303   74.000000
# 32  -21.778114   46.222221  187.333328  132.872614  54.460714   52.777779
# 33    3.390805   69.111115         NaN  135.915806        NaN         NaN
# 34  -14.129311   96.111115  194.000000  124.341145  69.658855  100.777779
#
#       pt2_vavg    pt2_vgps   pt2_vdiff    pt2_verr
# 0   151.625000         NaN         NaN   41.500000
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6    73.500000         NaN         NaN   47.333332
# 7          NaN         NaN         NaN         NaN
# 8   102.333336  143.208386  -40.875050   31.111111
# 9   354.000000  134.068561  219.931439   99.111115
# 10  117.444443         NaN         NaN   25.111111
# 11   34.333332         NaN         NaN   46.333332
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18  337.000000  226.816276  110.183724   68.555557
# 19  241.777771  211.457985   30.319786   64.444443
# 20  530.555542  133.440853  397.114689  104.333336
# 21  174.666672  144.000240   30.666431   60.111111
# 22         NaN         NaN         NaN         NaN
# 23  274.666656         NaN         NaN   74.000000
# 24         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN
# 27  102.333336  186.941698  -84.608362   35.833332
# 28  114.666664  184.275215  -69.608551   30.444445
# 29         NaN         NaN         NaN         NaN
# 30  102.333336  149.318331  -46.984995   54.111111
# 31   82.444443  142.577768  -60.133326   72.777779
# 32  128.333328  140.524285  -12.190957   46.111111
# 33  172.777771  141.636546   31.141225   66.000000
# 34   95.111115  137.336804  -42.225689   95.777779
#
# [35 rows x 56 columns]

# %%
df = df.replace(-np.inf, np.nan)
df = df.replace(np.inf, np.nan)
df.to_csv('../results_ITSLIVE.csv', index=False)

# %%
gps
# Out:
#    Unnamed: 0       date1       date2  start_easting  start_northing  \
# 0           0  2018-10-05  2018-09-30  621383.084841    6.738920e+06
# 1           1  2018-10-05  2018-09-30  610531.630118    6.737073e+06
# 2           2  2018-10-05  2018-09-30  601810.429736    6.733774e+06
#
#      end_easting  end_northing  distance_traveled (m)  velocity (m/d)  \
# 0  621381.738315  6.738918e+06               2.015470       -0.403094
# 1  610530.195434  6.737074e+06               1.703303       -0.340661
# 2  601809.124834  6.733773e+06               1.881326       -0.376265
#
#    start_easting_3413  start_northing_3413  end_easting_3413  \
# 0       -3.227459e+06        212767.842312     -3.227460e+06
# 1       -3.228240e+06        224145.144740     -3.228239e+06
# 2       -3.230736e+06        233478.821992     -3.230737e+06
#
#    end_northing_3413                         geometry   vx (m/yr)   vy (m/yr)  \
# 0      212769.385111  POINT (-3227460.401 212769.385)  102.707969 -112.624285
# 1      224146.528571  POINT (-3228239.026 224146.529)  -79.947760 -101.019600
# 2      233480.308331  POINT (-3230737.265 233480.308)   92.088135 -108.502758
#
#      v (m/yr)
# 0  147.129311
# 1  124.341145
# 2  137.336804

# %%
gps_xy
# Out:
# [(-3227460.40093354, 212769.38511073),
#  (-3228239.02608854, 224146.52857051),
#  (-3230737.26454084, 233480.30833112)]
