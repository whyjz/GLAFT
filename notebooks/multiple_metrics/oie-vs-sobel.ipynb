# %% [markdown]
# ## Comparing Metric #1 (off-ice error) and #2 (Sobel flow statistics)
#
# ### Analysis
#
# #### 1. Basic information, importing modules
#
# - Test area: **Kaskawulsh Glacier**
# - Test packages: **CARST, Vmap, GIV, autoRIFT**
# - Test pair: **Landsat 8 20180304-20180405**

# %%
# Developer's setting
# %load_ext autoreload
# %autoreload 2

# %%
# import gftt
import matplotlib.pyplot as plt
# import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib

# %% [markdown]
# #### 2. Load the feature tracking data list and the metrics for each test
#
# Each row is a feature tracking test using a specific parameter combination described in each field.

# %%
df = pd.read_csv('../results_agu21.csv', dtype=str)
df['OIE-x'] = df['OIE-x'].astype(float)
df['OIE-y'] = df['OIE-y'].astype(float)
df['SS-x'] = df['SS-x'].astype(float)
df['SS-y'] = df['SS-y'].astype(float)
demo = df
demo
# Out:
#                      Date Chip (px) Resolution (px) Prefilter  \
# 0   LS8-20180304-20180405        32               1       Gau
# 1   LS8-20180304-20180405        32               1      NAOF
# 2   LS8-20180304-20180405        32               1      None
# 3   LS8-20180304-20180405        32               4       Gau
# 4   LS8-20180304-20180405        32               4      NAOF
# 5   LS8-20180304-20180405        32               4      None
# 6   LS8-20180304-20180405        32               8       Gau
# 7   LS8-20180304-20180405        32               8      NAOF
# 8   LS8-20180304-20180405        32               8      None
# 9   LS8-20180304-20180405        64               1       Gau
# 10  LS8-20180304-20180405        64               1      NAOF
# 11  LS8-20180304-20180405        64               1      None
# 12  LS8-20180304-20180405        64               4       Gau
# 13  LS8-20180304-20180405        64               4      NAOF
# 14  LS8-20180304-20180405        64               4      None
# 15  LS8-20180304-20180405        64               8       Gau
# 16  LS8-20180304-20180405        64               8      NAOF
# 17  LS8-20180304-20180405        64               8      None
# 18  LS8-20180304-20180405     multi              16      NAOF
# 19  LS8-20180304-20180405     multi               4      NAOF
# 20  LS8-20180304-20180405     multi              16       Gau
# 21  LS8-20180304-20180405     multi               4       Gau
# 22  LS8-20180304-20180405     multi              16      None
# 23  LS8-20180304-20180405     multi               4      None
# 24  LS8-20180304-20180405        31               1       Gau
# 25  LS8-20180304-20180405        65               1       Gau
# 26  LS8-20180304-20180405        31               1      None
# 27  LS8-20180304-20180405        65               1      None
# 28  LS8-20180304-20180405        31               1       LoG
# 29  LS8-20180304-20180405        31               1       LoG
# 30  LS8-20180304-20180405        32               4      None
# 31  LS8-20180304-20180405        32               8      None
# 32  LS8-20180304-20180405        64               4      None
# 33  LS8-20180304-20180405        64               8      None
# 34  LS8-20180304-20180405        32               4       Gau
# 35  LS8-20180304-20180405        32               8       Gau
# 36  LS8-20180304-20180405        64               4       Gau
# 37  LS8-20180304-20180405        64               8       Gau
# 38  LS8-20180304-20180405        32               4      NAOF
# 39  LS8-20180304-20180405        32               8      NAOF
# 40  LS8-20180304-20180405        64               4      NAOF
# 41  LS8-20180304-20180405        64               8      NAOF
#
#                  Subpixel  Software  \
# 0    16-node oversampling     CARST
# 1    16-node oversampling     CARST
# 2    16-node oversampling     CARST
# 3    16-node oversampling     CARST
# 4    16-node oversampling     CARST
# 5    16-node oversampling     CARST
# 6    16-node oversampling     CARST
# 7    16-node oversampling     CARST
# 8    16-node oversampling     CARST
# 9    16-node oversampling     CARST
# 10   16-node oversampling     CARST
# 11   16-node oversampling     CARST
# 12   16-node oversampling     CARST
# 13   16-node oversampling     CARST
# 14   16-node oversampling     CARST
# 15   16-node oversampling     CARST
# 16   16-node oversampling     CARST
# 17   16-node oversampling     CARST
# 18  interest point groups       GIV
# 19  interest point groups       GIV
# 20  interest point groups       GIV
# 21  interest point groups       GIV
# 22  interest point groups       GIV
# 23  interest point groups       GIV
# 24              parabolic      Vmap
# 25              parabolic      Vmap
# 26              parabolic      Vmap
# 27              parabolic      Vmap
# 28              parabolic      Vmap
# 29        affine adaptive      Vmap
# 30                  pyrUP  autoRIFT
# 31                  pyrUP  autoRIFT
# 32                  pyrUP  autoRIFT
# 33                  pyrUP  autoRIFT
# 34                  pyrUP  autoRIFT
# 35                  pyrUP  autoRIFT
# 36                  pyrUP  autoRIFT
# 37                  pyrUP  autoRIFT
# 38                  pyrUP  autoRIFT
# 39                  pyrUP  autoRIFT
# 40                  pyrUP  autoRIFT
# 41                  pyrUP  autoRIFT
#
#                                                    Vx  \
# 0   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 1   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 2   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 3   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 4   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 5   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 6   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 7   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 8   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 9   /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 10  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 11  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 12  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 13  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 14  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 15  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 16  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 17  /home/jovyan/Projects/PX_comparison/PX/CARST/2...
# 18  /home/jovyan/Projects/PX_comparison/PX/GIV/u_l...
# 19  /home/jovyan/Projects/PX_comparison/PX/GIV/u_l...
# 20  /home/jovyan/Projects/PX_comparison/PX/GIV/u_l...
# 21  /home/jovyan/Projects/PX_comparison/PX/GIV/u_l...
# 22  /home/jovyan/Projects/PX_comparison/PX/GIV/u_l...
# 23  /home/jovyan/Projects/PX_comparison/PX/GIV/u_l...
# 24  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...
# 25  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...
# 26  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...
# 27  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...
# 28  /home/jovyan/Projects/PX_comparison/PX/Vmap/su...
# 29  /home/jovyan/Projects/PX_comparison/PX/Vmap/su...
# 30  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 31  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 32  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 33  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 34  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 35  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 36  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 37  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 38  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 39  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 40  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
# 41  /home/jovyan/Projects/PX_comparison/PX/autoRIF...
#
#                                                    Vy     OIE-x     OIE-y  \
# 0   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.417480  0.454102
# 1   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.417480  0.476074
# 2   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.673828  0.571289
# 3   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.402832  0.410156
# 4   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.351562  0.292969
# 5   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.615234  0.556641
# 6   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.382690  0.380859
# 7   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.382690  0.369873
# 8   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.593262  0.541992
# 9   /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.278320  0.270996
# 10  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.080566  0.087891
# 11  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.476074  0.461426
# 12  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.227051  0.230713
# 13  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.087891  0.087891
# 14  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.446777  0.380859
# 15  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.219727  0.250854
# 16  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.087891  0.087891
# 17  /home/jovyan/Projects/PX_comparison/PX/CARST/2...  0.439453  0.391846
# 18  /home/jovyan/Projects/PX_comparison/PX/GIV/v_l...  0.233542  0.277519
# 19  /home/jovyan/Projects/PX_comparison/PX/GIV/v_l...  0.813247  0.575565
# 20  /home/jovyan/Projects/PX_comparison/PX/GIV/v_l...  0.251201  0.399150
# 21  /home/jovyan/Projects/PX_comparison/PX/GIV/v_l...  0.235697  0.388085
# 22  /home/jovyan/Projects/PX_comparison/PX/GIV/v_l...  0.614010  0.767214
# 23  /home/jovyan/Projects/PX_comparison/PX/GIV/v_l...  0.367257  0.470482
# 24  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...  0.280396  0.281501
# 25  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...  0.157598  0.179982
# 26  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...  0.547266  0.479374
# 27  /home/jovyan/Projects/PX_comparison/PX/Vmap/pa...  0.579469  0.524274
# 28  /home/jovyan/Projects/PX_comparison/PX/Vmap/su...  0.464195  0.469295
# 29  /home/jovyan/Projects/PX_comparison/PX/Vmap/su...  0.748049  0.918787
# 30  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  1.040039  1.157227
# 31  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.703125  0.688477
# 32  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  1.010742  0.805664
# 33  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.776367  0.717773
# 34  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.651855  0.725098
# 35  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.380859  0.468750
# 36  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.351562  0.380859
# 37  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.249023  0.336914
# 38  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.219727  0.322266
# 39  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.146484  0.249023
# 40  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.117188  0.234375
# 41  /home/jovyan/Projects/PX_comparison/PX/autoRIF...  0.117188  0.205078
#
#         SS-x      SS-y
# 0   1.166369  1.127073
# 1   2.158645  2.070151
# 2   1.714556  1.417194
# 3   1.410858  1.372896
# 4   2.057519  2.450102
# 5   2.446684  2.084638
# 6   1.634630  1.529421
# 7   2.254367  2.527121
# 8   2.994531  2.803851
# 9   0.624580  0.556641
# 10  0.937500  0.867603
# 11  0.850114  0.719117
# 12  0.726908  0.660968
# 13  1.056314  1.056517
# 14  1.313631  1.141075
# 15  0.855555  0.897867
# 16  1.028525  1.533353
# 17  1.687681  1.583285
# 18  2.309538  2.666533
# 19  3.832090  3.621216
# 20  2.791979  3.616469
# 21  3.829151  4.109152
# 22  4.842514  6.934244
# 23  3.573858  4.022872
# 24  0.903663  0.734030
# 25  0.394870  0.331545
# 26  1.278607  1.003679
# 27  1.055869  0.939092
# 28  1.020549  0.885100
# 29  2.355224  2.479468
# 30  4.148380  3.802956
# 31  2.202143  2.200681
# 32  3.562432  3.283342
# 33  2.759822  2.894911
# 34  2.405200  2.317973
# 35  1.528500  1.593922
# 36  1.584471  1.508149
# 37  1.286396  1.426851
# 38  0.982647  1.074840
# 39  0.878906  1.058343
# 40  0.709202  0.796961
# 41  0.615931  0.774014

# %% [markdown]
# #### 3. Sobel flow statistics VS Off-ice error

# %%
sns.scatterplot(data=demo, x='OIE-x', y='SS-x', hue='Software')
# Out:
# <AxesSubplot:xlabel='OIE-x', ylabel='SS-x'>

# %%
sns.scatterplot(data=demo, x='OIE-y', y='SS-y', hue='Software')
# Out:
# <AxesSubplot:xlabel='OIE-y', ylabel='SS-y'>

# %%
sns.scatterplot(data=demo, x='OIE-x', y='SS-x', hue='Resolution (px)')
# Out:
# <AxesSubplot:xlabel='OIE-x', ylabel='SS-x'>

# %%
sns.scatterplot(data=demo, x='OIE-x', y='SS-x', hue='Chip (px)')
# Out:
# <AxesSubplot:xlabel='OIE-x', ylabel='SS-x'>

# %%
fig, ax5 = plt.subplots(1, 1, figsize=(20, 20))

sns.scatterplot(data=demo, x='OIE-x', y='SS-x', hue='Prefilter', ax=ax5)

for idx, row in demo.iterrows():
    label = '-'.join((row.Software, row['Chip (px)'], row['Resolution (px)'], row.Prefilter)) + '\n' + row.Subpixel
    ax5.text(row['OIE-x'] + 0.01, row['SS-x'] + 0.04, label)

# %% [markdown]
# #### 4. AGU 2021 poster, Figure 3

# %%
# font = {'family' : 'normal',
#         'weight' : 'bold',
#         'size'   : 22}
font = {'size'   : 20}
matplotlib.rc('font', **font)
matplotlib.rc('legend', fontsize=16)
axes_settings = {'linewidth'   : 2}
matplotlib.rc('axes', **axes_settings)
fig, ax6 = plt.subplots(1, 1, figsize=(7, 7))
sns.scatterplot(data=demo, x='OIE-x', y='SS-x', hue='Prefilter', style='Software', s=160, ax=ax6, legend='full')
ax6.set_xlabel('Off-ice area error (m/day)')
ax6.set_ylabel('On-ice edge richness (m/day)')
ax6.set_xlim(0, 1.2)
legend = ax6.get_legend()
# legend.set_size(10)
legend.get_frame().set_linewidth(2)
fig.patch.set_facecolor('xkcd:white')
# fig.savefig('OIE-vs-SS_updated.svg')
